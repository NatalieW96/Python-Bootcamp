# %% [markdown]
# # Practical Session 3: Lists, Tuples, Sets & Dictionaries

# %% [markdown]
# #### 1. List Manipulation

# %% [markdown]
# Create a list temperatures representing daily temperatures (°C) for a week: 23, 25, 21, 20, 22.
# Then:
# - Add a temperature reading for a new day, 24.
# - Insert a missing temperature 19 at the second position.
# - Remove the temperature 20.
# - Print the final list and its length.

# %% [markdown]
# #### 2. List indexing and slicing

# %% [markdown]
# Given the list of recorded pH values in an experiment:

# %%
ph_values = [7.2, 7.4, 6.8, 7.0, 7.1, 6.9]

# %% [markdown]
# - Print the first pH value
# - Print the last three pH values using slicing
# - Print the pH values in reverse order using slicing

# %% [markdown]
# #### 3. Nested Lists

# %% [markdown]
# Create a 3x3 matrix using nested lists where each element is a list of [R,G,B] colour values (numbers from 0 to 255).
# Then:
# 1. Print the green value of the pixel in the second row, first column
# 2. Change the blue value of the pixel in the first row, second column
# 3. Print the updated matrix

# %% [markdown]
# #### 4. Tuples

# %% [markdown]
# You have tuples representing the incoming calibrated and normalised light flux from a star system over three days:

# %%
day1 = (135.5, 137.0)           #(observed_flux_start, observed_flux_end)
day2 = (136.0, 135.0)
day3 = (134.5, 136.5)

# %% [markdown]
# 1. Unpack each day and print for each day the start, end and change such as:
#
# `Day 1: flux_start = 135.5, flux_end = 137.0, change = 1.5`
#
# 2. Create a tuple containing the daily flux differences (end - start) for each day.
#
# 3. Calculate the total flux change over the three days by summing these differences.
#
# 4. Create a new tuple adding day 4’s flux observations (137.5, 138.0) to the existing data.

# %% [markdown]
# #### 5. Sets

# %% [markdown]
# Create two sets:

# %%
observed_morning = {"sparrow", "robin", "finch"}
observed_afternoon = {"finch", "cardinal", "robin"}

# %% [markdown]
# 1. Print all the birds observed in the day.
#
# 2. Print the birds that were observed in both the morning and afternoon.
#
# 3. Print only the species observed in the morning, but not in the afternoon.
#
# 4. Add a blue jay to the observed birds in the morning
#
# 5. Remove robin from the birds observed in the afternoon
#
# 6. Check if a cardinal was observed in the morning

# %% [markdown]
# #### 6. Dictionaries

# %% [markdown]
# Create a dictionary called `book1`, which contains the `title`, `author` and `year` of your favourite book.
#
# Then:
#
# 1. Print the author's name
#
# 2. Add a new key "Checked out" and set it to a boolean
#
# 3. Change the year to this year, there's been a reprint
#
# 4. Now with your book dictionry, make a nested library dictionary where your book is one of 3 books (with 2 other books of your choice). Each book is identified with a barcode number.
#
# 5. Using the library nested dictionary, print the author and title of the last book, and if it's checked out.
#
# 6. Add a genre catagory for each book, with multiple genres contained in a list
#
# 7. Someone stole a book, remove the second book for your library.
